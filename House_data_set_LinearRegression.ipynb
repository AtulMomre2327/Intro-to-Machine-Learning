# %% [markdown]
# <a href="https://colab.research.google.com/github/AtulMomre2327/Intro-to-Machine-Learning/blob/main/House_data_set_LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/Data  Set/dataset_2.csv')

# %%
df.head()
# Out:
#      Area_SqFt  Rooms  Build_Year Location       Street_Type      Furnishing  \
# 0  2473.192784    4.0        1992   Jaipur  Residential Lane       Furnished
# 1  2353.472711    4.0        2006   Indore       Corner Plot     Unfurnished
# 2  2212.222005    3.0        2012   Jaipur    Highway Facing  Semi-Furnished
# 3  2823.886596    6.0        1993  Lucknow         Main Road     Unfurnished
# 4  1869.648721    5.0        2012   Jaipur       Corner Plot  Semi-Furnished
#
#   Property_Type Has_Pool     Price
# 0     Apartment       No  568486.0
# 1     Apartment      Yes  577214.0
# 2        Duplex       No  581300.0
# 3         Villa      Yes  794614.0
# 4     Apartment       No  493086.0

# %%
df.describe()
# Out:
#           Area_SqFt        Rooms   Build_Year         Price
# count   1091.000000  1091.000000  1124.000000  1.124000e+03
# mean    2237.479473     4.568286  2005.080071  6.082015e+05
# std      731.097828     1.678155    11.708876  1.431958e+05
# min      700.000000     2.000000  1985.000000  2.486400e+05
# 25%     1834.022964     3.000000  1995.000000  5.161948e+05
# 50%     2201.545784     5.000000  2005.000000  6.025410e+05
# 75%     2576.139355     6.000000  2015.000000  6.895785e+05
# max    10267.124330     7.000000  2024.000000  2.071402e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1124 entries, 0 to 1123
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Area_SqFt      1091 non-null   float64
#  1   Rooms          1091 non-null   float64
#  2   Build_Year     1124 non-null   int64
#  3   Location       1124 non-null   object
#  4   Street_Type    1124 non-null   object
#  5   Furnishing     1091 non-null   object
#  6   Property_Type  1124 non-null   object
#  7   Has_Pool       1124 non-null   object
#  8   Price          1124 non-null   float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 79.2+ KB

# %%
df.isnull().sum()
# Out:
# Area_SqFt        33
# Rooms            33
# Build_Year        0
# Location          0
# Street_Type       0
# Furnishing       33
# Property_Type     0
# Has_Pool          0
# Price             0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Area_SqFt        0
# Rooms            0
# Build_Year       0
# Location         0
# Street_Type      0
# Furnishing       0
# Property_Type    0
# Has_Pool         0
# Price            0
# dtype: int64

# %%
df.shape
# Out:
# (1027, 9)

# %%
# Column encoding
df = pd.get_dummies(df,columns = ['Location','Street_Type','Furnishing','Property_Type','Has_Pool'],drop_first = True)

# %%
x = df.drop(columns =['Price'])
y = df['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
x_train.head()
# Out:
#        Area_SqFt  Rooms  Build_Year  Location_Gurugram  Location_Indore  \
# 677  2503.537285    5.0        1992              False            False
# 290  2215.373300    6.0        1988              False            False
# 639  2417.689367    6.0        2020              False            False
# 512  2151.575542    7.0        2013              False            False
# 709  2225.060135    4.0        1998              False            False
#
#      Location_Jaipur  Location_Kanpur  Location_Lucknow  Location_Noida  \
# 677             True            False             False           False
# 290            False             True             False           False
# 639            False            False             False            True
# 512            False            False              True           False
# 709             True            False             False           False
#
#      Location_Prayagraj  Street_Type_Gated Society  \
# ...

# %%
y_train.head()
# Out:
# 677    656681.0
# 290    562495.0
# 639    650928.0
# 512    652572.0
# 709    545932.0
# Name: Price, dtype: float64

# %%
x_test.head()
# Out:
#        Area_SqFt  Rooms  Build_Year  Location_Gurugram  Location_Indore  \
# 469  1558.569158    7.0        2007              False            False
# 580  2522.391190    5.0        2024              False            False
# 426  1415.491593    7.0        2007              False            False
# 115  1179.867808    7.0        1985              False            False
# 464  1958.020398    5.0        1999               True            False
#
#      Location_Jaipur  Location_Kanpur  Location_Lucknow  Location_Noida  \
# 469            False             True             False           False
# 580            False            False              True           False
# 426             True            False             False           False
# 115            False            False              True           False
# 464            False            False             False           False
#
#      Location_Prayagraj  Street_Type_Gated Society  \
# ...

# %%
y_test.head()
# Out:
# 469    423257.0
# 580    690207.0
# 426    454653.0
# 115    404564.0
# 464    605938.0
# Name: Price, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
train_pred = model.predict(x_train)
print(train_pred)
# Out:
# [ 633806.63667472  557127.11036988  642566.12454386  652957.1866762
#   527170.48727269  534982.72895957  524686.07695804  549155.77735384
#   787715.51650521  768189.21409475  521851.75916999  700772.71754531
#   472580.57431849  535107.20143487  564399.53346084  681675.938539
#   643572.22219288  656972.88028354  800359.19441613  745840.66187211
#   815667.77404678  724352.04542171  428031.4212174   576520.21569508
#   897252.2934127   596604.64381756  501470.37595456  665640.54927285
#   682834.62025907  792520.1624988   610959.5105231   635393.82393031
#   503786.56745489  641460.47091913  762048.97373952  672659.47159672
#   645738.39670566  429820.828679    559435.10946551  494111.01957882
#   447524.18249112  489628.58257647  531760.17965209  488736.46678897
#   619529.37654291  575120.57784423  557339.3208051   856828.91005163
#   496639.02122566  555059.52546087  603815.31916816  500029.34392909
#   688620.93563953  540734.76625956  505082.29260057  613975.67714383
# ...

# %%
test_pred = model.predict(x_test)
print(test_pred)
# Out:
# [ 469536.05833049  697169.17749953  446700.48403528  443099.15566653
#   603669.0237335   694851.52899235  656336.92019561  547244.0410703
#   672507.40775646  511516.40283701  719245.33900725  543949.98379726
#   601803.9195776   409482.17238737  301146.06170519  729824.73100502
#   725417.6881408   512010.56198489  494729.4635404   498209.40724955
#   633305.50645088  781403.90050173  764089.90327165  633790.16059885
#   711439.41333812  535883.38247296  571799.32812315  768496.24463039
#   643622.9798736   672224.41554833  768546.42582163  611491.12595025
#   636335.24640791  445951.35241356  351831.22878606 1254440.36855393
#   824978.23268635  670594.17022842  629726.31260479  619384.43325281
#   762505.63476191  517759.85237952  668175.66128066  425261.09911659
#   528603.1197231   615371.74595583  465547.04898269  635677.60469216
#   542717.54554189  708678.16919715  375299.76292118  680935.77463613
#   581784.8679595   512864.38752027  628891.11817387  475128.65752756
# ...

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,mean_absolute_percentage_error

# %%
print('Train mean_squared_error :-',mean_squared_error(y_train,train_pred))
print('Train mean_absolute_error :-',mean_absolute_error(y_train,train_pred))
print('Train mean_absolute_percentage_error :-',mean_absolute_percentage_error(y_train,train_pred)*100)
print('Train R2 score ',r2_score(y_train,train_pred))
# Out:
# Train mean_squared_error :- 946924570.4490764
# Train mean_absolute_error :- 18390.575310728
# Train mean_absolute_percentage_error :- 3.0150194155467767
# Train R2 score  0.9568602562021604

# %%
print('Test mean_squared_error :- ',mean_squared_error(y_test,test_pred))
print('Test mean_absolute_error :-',mean_absolute_error(y_test,test_pred))
print('Test mean_absolute_percentage_error :-',mean_absolute_percentage_error(y_test,test_pred)*100)
print('Test R2 score ',r2_score(y_test,test_pred))
# Out:
# Test mean_squared_error :-  515916154.351647
# Test mean_absolute_error :- 18429.112798823342
# Test mean_absolute_percentage_error :- 3.2873272512118143
# Test R2 score  0.9701944738745564
